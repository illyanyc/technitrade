# %%
import pandas as pd
import os, time
import technicals

# !pip install alpaca-trade-api

os.chdir("../marketdata")
import yahoo
import alpaca

# %%
from datetime import date, datetime, timedelta

end_date  = datetime.now()
start_date  = (end_date - timedelta(days=1000))

start_date = start_date.strftime('%Y-%m-%d')
end_date = end_date.strftime('%Y-%m-%d')

print(f"Start date : {start_date}")
print(f"End date : {end_date}")
# Out:
# Start date : 2018-10-14
# End date : 2021-07-10

# %%
# Tickers
test_tickers = ["AAPL","ADSK","D","PFE"]

# %%
# Get market data 
ohlcv_df = alpaca.ohlcv(test_tickers, start_date=start_date, end_date=end_date)

# %%
ohlcv_df.head()
# Out:
#                              AAPL                                      \
#                              open    high       low   close    volume
# time
# 2018-10-15 00:00:00-04:00  221.16  221.83  217.2700  217.28  22403259
# 2018-10-16 00:00:00-04:00  218.93  222.99  216.7627  222.13  21865043
# 2018-10-17 00:00:00-04:00  222.30  222.64  219.3400  221.20  16169647
# 2018-10-18 00:00:00-04:00  217.86  219.74  213.0000  216.12  23483746
# 2018-10-19 00:00:00-04:00  219.16  221.26  217.4300  219.30  23788682
#
#                                ADSK                                       \
#                                open    high       low   close     volume
# time
# 2018-10-15 00:00:00-04:00  138.4700  139.32  132.7987  134.60  1928807.0
# 2018-10-16 00:00:00-04:00  137.7500  141.80  136.6200  141.42  2011114.0
# 2018-10-17 00:00:00-04:00  141.1800  142.10  138.7000  141.82  1295773.0
# 2018-10-18 00:00:00-04:00  140.7600  141.45  135.7600  137.28  1793153.0
# 2018-10-19 00:00:00-04:00  138.8099  140.43  133.1001  133.18  2883838.0
#
#                                D                                   PFE  \
#                             open   high     low  close   volume   open
# time
# 2018-10-15 00:00:00-04:00  71.31  71.90  71.015  71.61  2392609  43.65
# 2018-10-16 00:00:00-04:00  71.74  72.63  71.620  72.28  1859051  43.35
# 2018-10-17 00:00:00-04:00  72.14  72.56  71.690  72.30  1631605  43.77
# 2018-10-18 00:00:00-04:00  72.28  72.79  71.960  72.26  1682603  44.34
# 2018-10-19 00:00:00-04:00  72.17  73.99  72.170  73.50  3451117  44.05
#
#
#                              high    low  close    volume
# time
# 2018-10-15 00:00:00-04:00  43.710  42.98  43.11  17246091
# 2018-10-16 00:00:00-04:00  43.980  43.04  43.92  17011168
# 2018-10-17 00:00:00-04:00  44.795  43.75  44.57  16097583
# 2018-10-18 00:00:00-04:00  44.500  43.71  44.02  16628176
# 2018-10-19 00:00:00-04:00  44.830  43.98  44.48  14384473

# %%
tech_ind = technicals.TechnicalAnalysis(ohlcv_df)

# %%
ticker_df = tech_ind.get_all_technicals("ADSK")

# %%
ticker_df = ticker_df[14:-14]

# %%
ticker_df.tail()
# Out:
#                              open     high       low   close     volume  \
# time
# 2021-06-14 00:00:00-04:00  278.12  281.280  276.7600  280.44   981521.0
# 2021-06-15 00:00:00-04:00  281.26  281.715  275.9700  276.77   876982.0
# 2021-06-16 00:00:00-04:00  277.00  278.315  271.2500  273.73  1028801.0
# 2021-06-17 00:00:00-04:00  272.16  278.800  271.1506  276.34  1671586.0
# 2021-06-18 00:00:00-04:00  275.73  281.130  275.0100  278.09  1114340.0
#
#                                  rsi   williams        mfi    stoch_k  \
# time
# 2021-06-14 00:00:00-04:00  49.220016 -59.889858  50.111632   6.670393
# 2021-06-15 00:00:00-04:00  45.811553 -76.732446  42.903951  -6.536845
# 2021-06-16 00:00:00-04:00  43.159030 -87.753086  35.655765 -16.106279
# 2021-06-17 00:00:00-04:00  46.033379 -74.498511  42.816417   1.587656
# 2021-06-18 00:00:00-04:00  47.925143 -57.320688  50.041730  15.886678
#
#                                macd  ...       ema_7      ema_14      ema_21  \
# time                                 ...
# 2021-06-14 00:00:00-04:00 -1.349857  ...  278.979135  279.883243  280.590779
# 2021-06-15 00:00:00-04:00 -1.479579  ...  278.426851  279.468144  280.243435
# 2021-06-16 00:00:00-04:00 -1.806859  ...  277.252638  278.703058  279.651305
# 2021-06-17 00:00:00-04:00 -1.834479  ...  277.024479  278.387984  279.350277
# 2021-06-18 00:00:00-04:00 -1.695612  ...  277.290859  278.348252  279.235706
#
#                            highlow  closeopen     bb_high      bb_low  \
# time
# 2021-06-14 00:00:00-04:00   4.5200       2.32  291.540105  269.651800
# 2021-06-15 00:00:00-04:00   5.7450      -4.49  291.551186  269.571195
# 2021-06-16 00:00:00-04:00   7.0650      -3.27  291.620560  269.401821
# 2021-06-17 00:00:00-04:00   7.6494       4.18  291.393254  269.971032
# 2021-06-18 00:00:00-04:00   6.1200       2.36  291.218414  270.537300
#
#                                     pvt  daily_return  cum_daily_return
# time
# 2021-06-14 00:00:00-04:00  10368.822523      0.010595          2.083507
# 2021-06-15 00:00:00-04:00 -21875.510634     -0.013087          2.056241
# 2021-06-16 00:00:00-04:00    176.498301     -0.010984          2.033655
# 2021-06-17 00:00:00-04:00  27238.672803      0.009535          2.053046
# 2021-06-18 00:00:00-04:00  -8881.609200      0.006333          2.066048
#
# [5 rows x 23 columns]

# %% [markdown]
# ---
# ## Technical Indicators

# %% [markdown]
# ### RSI - Relative Strenght Index
#
# $$RSI = 100 - \left(\frac{100}{1+Relative\:Strenght}\right)$$
#
# where:
# *relative strenght* (*RS*)= *average gain* - *average loss*
#
# [Relative Strenght Index](https://www.investopedia.com/terms/r/rsi.asp)

# %%
ticker_df[['rsi', 'cum_daily_return']].plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>],
#       dtype=object)

# %% [markdown]
# #### Williams %R - William's Percent Range
#
# $$Williams Percent Range=\left(\frac{Highest High-Close}{Highest High-Lowest Low}\right)$$
#
# where:<br>
# *Highest High* = Highest price in the lookback period.<br>
# *Close* = Most recent closing price.<br>
# *Lowest Low* = Lowest price in the lookback period.<br>
#
# [William %R](https://www.investopedia.com/terms/w/williamsr.asp)

# %%
ticker_df[['williams', 'cum_daily_return']].plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>],
#       dtype=object)

# %% [markdown]
# #### Aroon Indicator
#
# $$Aroon\:Up= \frac{a_{period} - n_{periods}\:since\:a_{period} max}{a_{period}} * 100$$
#
# $$Aroon\:Down= \frac{a_{period} - n_{periods}\:since\:a_{period} min}{a_{period}} * 100$$
#
# $$Aroon\:Oscillator=Aroon\:Up - Aroon\:Down$$
#
# where:
# *where **a<sub>period</sub>** = period of time to be measured*
#
# [Aroon Oscillator](https://www.investopedia.com/terms/a/aroon.asp)

# %%
# ticker_df[['aroon', 'close']].plot(subplots=True)

# %% [markdown]
# ### Money Flow Index
#
# * Positive money flow is calculated by adding the money flow of all the days where the typical price is higher than the previous day's typical price.
# * Negative money flow is calculated by adding the money flow of all the days where the typical price is lower than the previous day's typical price.
# * If typical price is unchanged then that day is discarded.
# * The money flow is divided into positive and negative money flow.
#
# $$Typical\:Price= \frac{(High + Low + Close)}{3}$$
#
# $$Raw\:Money\:Flow= Typical\:Price\:*\:Volume$$
#
# $$Money\:Flow\:Ratio= \frac{14-period\:Positive\:Money\:Flow}{(14-period\:Negative\:Money Flow)}$$
#
# $$Money\:Flow\:Index= 100 - \frac{100}{(1 + Money\:Flow\:Ratio)}$$
#
# [Money flowindex](https://en.wikipedia.org/wiki/Money_flow_index)

# %%
ticker_df[['mfi', 'cum_daily_return']].plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>],
#       dtype=object)

# %% [markdown]
# ### Stoichastic Oscillator
#
# $$Stoichastic\:Oscillator= \left(\frac{Close - Low_n}{High_n - Low_n}\right) * 100$$
#
# where:
# * C = The most recent closing price
# * Low<sub>*n*</sub> = The lowest price traded of the *n* previous trading sessions
# * High<sub>*n*</sub> = The highest price traded during the same *n*-day period
# * %K = The current value of the stochastic indicator
#
#
# [Stochastic Oscillator](https://www.investopedia.com/terms/s/stochasticoscillator.asp)

# %%
ticker_df[['stoch_k', 'cum_daily_return']].plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>],
#       dtype=object)

# %% [markdown]
# ### MACD
#
# $$PVT= \left[\left(\frac{Current\:Close - Previous\:Close}{Previous\:Close}\right)*Volume\right] + Previous\:PVT$$
#
# [MACD](https://www.investopedia.com/terms/m/macd.asp)

# %%
ticker_df[['macd', 'cum_daily_return']].plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>],
#       dtype=object)

# %% [markdown]
# ### Moving Average
#
# $$Moving\:Average=\frac{A_1 + A_2 + A_3}{n}$$
#
# where:
#
# * *A* = Average in period *n*
# * *n* = Number of time periods
#
# [Moving Average](https://www.investopedia.com/terms/m/movingaverage.asp)

# %%
ticker_df[['ma_10', 'ma_50', 'ma_200']].plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>,
#        <AxesSubplot:xlabel='time'>], dtype=object)

# %% [markdown]
# ### Exponential Moving Average
#
# $$EMA_t=\left[V_t * \left(\frac{s}{1+d}\right)\right]+EMA_y$$
#
# where:
#
# * *EMA<sub>t</sub>* = = EMA today
# * *EMA<sub>y</sub>* = = EMA yesterday
# * *V<sub>t</sub>* = Value today
# * *s* = smoothing
# * *d* = number of days
#
# [Exponential Moving Average](https://www.investopedia.com/terms/m/movingaverage.asp)

# %%
ticker_df[['ema_7', 'ema_14', 'ema_21']].plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>,
#        <AxesSubplot:xlabel='time'>], dtype=object)

# %% [markdown]
# ### High Low
#
# $$High\:Low = High - Low$$
#
# Difference between the high and low prices of the day

# %%
ticker_df[['highlow','cum_daily_return']].plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>],
#       dtype=object)

# %% [markdown]
# ### Close Open
#
# $$Close\:Open = Close - Open$$
#
# Difference between the close and open prices of the day

# %%
ticker_df[['closeopen','cum_daily_return']].plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>],
#       dtype=object)

# %% [markdown]
# ### Bollinger Bands
#
# $$Bollinger\:High=Moving\:Average + m * σ[Closing\:Price, n]$$
# $$Bollinger\:Low=Moving\:Average - m * σ[Closing\:Price, n]$$
#
# where:
# * *m* = number of standard deviations
# * *n* = number of days in the smoothing period
#
# [Bollinger Bands](https://www.investopedia.com/terms/b/bollingerbands.asp)

# %%
ticker_df[['bb_high','bb_low','cum_daily_return']].plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>,
#        <AxesSubplot:xlabel='time'>], dtype=object)
